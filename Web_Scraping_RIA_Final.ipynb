# %% [markdown]
# # RIA.ru Web Scraper

# %%
# Based on keyword and date parameters, scrapes article text from RIA.ru 
# Script takes a keyword in English or Russian, 
# two four-digit years, and two one- or two-digit months
# Returns the data as a .txt file
# When importing into Excel, select UTF 8 and * as delim.

# %%
from urllib.request import urlopen
from urllib.parse import quote
from bs4 import BeautifulSoup
import pandas as pd
import re
import math

# getLinks----------------------------------------------------------------
# Function takes a keyword, two four-digit years, and two one- or two-digit months

def getLinks(query, yearStart, monthStart, yearEnd, monthEnd):
    
    # Make the query ASCII, if it's not
    # Add it to the search URL
    
    quoted_query = quote(query)
    searchURL = (f"https://ria.ru/search/?query={quoted_query}")
    
    # Create an empty list to hold links
    
    links = []
    
    # Pull the HTML while anticipating HTTP error
    
    try:
        html = urlopen(searchURL)
    
    except HTTPError as e:
        print(e)
    
    # If no HTTP error, then check for HTML error
    
    else:
        if html is None:
            print("URL is not found. Existing program.")
            exit()
            
        # If no HTML error, proceed with cleaning the HTML
        
        else:
            print("URL found.")
            bsObj = BeautifulSoup(html)        
       
    
    if bsObj.span is None:
        print("Tag was not found. Exiting program.") 
        exit()
    else:
        print("Tag found.")

    
    # Find and print number of hits 

    totalHits = (bsObj.find("div", {"class":"rubric-count m-active"}).get_text())
    totalHits = int(re.sub("[^0-9]", "", totalHits))     
    print("There are " + str(totalHits) + " hits for that key word combination.")
    print("Begin collecting relevant article links.")
    # Find the total number of cycles to go through 

    cycles = math.ceil(totalHits/20) 
    print("This will take " + str(cycles) + " cycles.")
        
    # Use a while statement to cycle through pages
    
    counter = 20
    while cycles > 0:
    
        print(str(cycles) + " cycles left.")
        
        # Collect page links based on span tag and data-url attribute.
        # Append it to the link list.
    
        for link in bsObj.findAll("span"):
            if 'data-url' in link.attrs:
                links.append(link.attrs['data-url'])
                #time.sleep(2)
        
        # Update search link and collect HTML for it

        searchURL = searchURL + "&offset=" + str(counter)
        html = urlopen(searchURL)
        bsObj = BeautifulSoup(html)
    
        counter = counter + 20
        cycles = cycles - 1
    
    print("There are " + str(len(links)) + " relevant articles before filtering by date.")
    print(" ")
    print(" ")
    print(" ")
    print("Now we will filter by date...")
    
    # Filter by date
    
    # Make year and month strings
    yearStart = str(yearStart)
    monthStart = str(monthStart)
    yearEnd = str(yearEnd)
    monthEnd = str(monthEnd)
    
    # If neccessary, add a proceeding 0 to the month inputs
    
    if len(monthStart) == 1:
        monthStart = "0" + monthStart
    else:
        monthStart = monthStart
    if len(monthEnd) == 1:
        monthEnd = "0" + monthEnd
    else:
        monthEnd = monthEnd
    
    # One month only
    if yearStart == yearEnd and monthStart == monthEnd:   
        # Combine year and month to form a match statement 
        match = yearStart + monthStart
        
        # Dates fall within links from index 15 to 21
        links = [link for link in links if link[15:21] == match]
        
        # Return relevant links 
        print(" ")
        print(" ")
        print("There are " + str(len(links)) + " relevant articles after filtering by date.")
        return links
    
    # Multiple months/years
    else:
        linksFiltered = []
        
        startParameter = int(yearStart + monthStart)
        endParameter = int(yearEnd + monthEnd)
        
        for link in links:
            if int(link[15:21])>= startParameter and int(link[15:21]) <= endParameter:
                linksFiltered.append(link)

         # Return relevant links 
        print(" ")
        print(" ")
        print("There are " + str(len(linksFiltered)) + " relevant articles after filtering by date.")
        return linksFiltered


# getMetaData----------------------------------------------------------------------
def getMetaData(linkURL):
    
    html = urlopen(linkURL)
    bsObj = BeautifulSoup(html.read());
    
    # Get the article title
    
    titleList = bsObj.findAll("", {"class":"article__title"})

    # Check to make sure it exists
    
    if len(titleList) == 0:
        title_return = "No title"
    
    # Makes a list of all tags that fit this parameter
    # Iterates through the list and then get text strips all tags from the text
    
    else:
        for title in titleList:
            title_return = title.get_text()            
        
    
    # Get the article date
    
    dList = bsObj.findAll("", {"itemprop": "dateModified"})
    
    # Check to make sure it exists
    
    if len(dList) == 0:
        date_return = "No date listed"
    
    # Makes a list of all tags that fit this parameter
    # Iterates through the list and then get text strips all tags from the text
    
    else:
        
        for d in dList:
            date_return = d.get_text()[0:10]
    
    # Get article tags
    
    tList = bsObj.findAll("", {"class":"article__tags"})

    # Check to make sure it exists
    
    if len(tList) == 0:
        tag_return = "No title listed"
        
    # Makes a list of all tags that fit this parameter
    # Iterates through the list and then get text strips all tags from the text
    
    else:
        
        for t in tList:
            tag_return = t.get_text()
    
    # Return items
    
    return title_return, date_return, tag_return


# getText------------------------------------------------------------------------
def getText(linkURL):
    text_return = " "
    html = urlopen(linkURL)
    bsObj = BeautifulSoup(html.read());
    
    # Get the aritcle text

    textList = bsObj.findAll("", {"class": "article__text"})
    
    
    if len(textList) == 0:
        text_return = "Text under a different tag"
    else:
        # Makes a list of all tags that fit this parameter
        for text in textList:
            # Iterates through the list and then get text strips all tags from the text
            text_return = text_return + (text.get_text())
    
    
    text_return = re.sub(r'[\n\r]+', '', text_return)
    
    
    return text_return
 
# scrapeRIA----------------------------------------------------------------
def scrapeRIA(query, yearStart, monthStart, yearEnd, monthEnd):
    global title_return, date_return, tag_return
    # Use getLinks to retrieve all the links and save to list pullList 
    
    pullList = getLinks(query, yearStart, monthStart, yearEnd, monthEnd)
    
    # Create empty lists to hold scraped content 
    
    URLsLst = []
    metadataLst = []
    textLst = []
    dateLst = []
    
    print(" ")
    print(" ")
    print("Scraping article text.")
   
    for link in pullList:
        print(link)
        URLsLst.append(link)
        print(" ")
        
        metadata = getMetaData(link)
        print(metadata)
        metadataLst.append(metadata)
        print(" ")
        
        text2 = getText(link)
        print(text2)
        textLst.append(text2)
        print(" ")
        
        dateLst.append(link[15:19] + "-" + link[19:21] + "-" + link[21:23])
    
    # Create an empty data frame
    print(" ")
    print(" ")
    print("Building data frame...")
    df = pd.DataFrame()
    
    # Add lists to data frame
    df["URLS"] = URLsLst
    df["metadata"] = metadataLst
    df["content"] = textLst
    df["date"] = dateLst
    
    
    print(df)
    print(" ")
    print(" ")
    print("Exporting data...")
    
    # Export data frame as a text file. 
    # When importing into Excel, select UTF 8 and * as delim.
    df.to_csv("RIA_data.txt", sep='*', index=False)

# Function takes a keyword, two four-digit years, and two one- or two-digit months
# Example searching cryptocurrency articles in May, 2019
scrapeRIA("криптовалюты", 2019, 5, 2019, 5)
# Out:
# URL found.
# Tag found.
# There are 1589 hits for that key word combination.
# Begin collecting relevant article links.
# This will take 80 cycles.
# 80 cycles left.
# 79 cycles left.
# 78 cycles left.
# 77 cycles left.
# 76 cycles left.
# 75 cycles left.
# 74 cycles left.
# 73 cycles left.
# 72 cycles left.
# 71 cycles left.
# 70 cycles left.
# 69 cycles left.
# 68 cycles left.
# 67 cycles left.
# 66 cycles left.
# 65 cycles left.
# 64 cycles left.
# 63 cycles left.
# 62 cycles left.
# 61 cycles left.
# 60 cycles left.
# 59 cycles left.
# 58 cycles left.
# 57 cycles left.
# 56 cycles left.
# 55 cycles left.
# 54 cycles left.
# 53 cycles left.
# 52 cycles left.
# 51 cycles left.
# 50 cycles left.
# 49 cycles left.
# 48 cycles left.
# 47 cycles left.
# 46 cycles left.
# 45 cycles left.
# 44 cycles left.
# 43 cycles left.
# 42 cycles left.
# 41 cycles left.
# 40 cycles left.
# 39 cycles left.
# 38 cycles left.
# 37 cycles left.
# 36 cycles left.
# 35 cycles left.
# 34 cycles left.
# 33 cycles left.
# 32 cycles left.
# 31 cycles left.
# 30 cycles left.
# 29 cycles left.
# 28 cycles left.
# 27 cycles left.
# 26 cycles left.
# 25 cycles left.
# 24 cycles left.
# 23 cycles left.
# 22 cycles left.
# 21 cycles left.
# 20 cycles left.
# 19 cycles left.
# 18 cycles left.
# 17 cycles left.
# 16 cycles left.
# 15 cycles left.
# 14 cycles left.
# 13 cycles left.
# 12 cycles left.
# 11 cycles left.
# 10 cycles left.
# 9 cycles left.
# 8 cycles left.
# 7 cycles left.
# 6 cycles left.
# 5 cycles left.
# 4 cycles left.
# 3 cycles left.
# 2 cycles left.
# 1 cycles left.
# There are 1589 relevant articles before filtering by date.
#
#
#
# Now we will filter by date...
#
#
# There are 15 relevant articles after filtering by date.
#
#
# Scraping article text.
# https://ria.ru/20190530/1555125701.html
#
# ('Стоимость биткоина впервые за год превысила девять тысяч долларов', '2019-05-30', 'биткоинЭкономика')
#
#  МОСКВА, 30 мая - РИА Новости. Стоимость самой популярной криптовалюты - биткоина - в четверг днем превысила 9 тысяч долларов впервые с мая 2018 года, свидетельствуют данные торгов.По данным портала CoinMarketCap, высчитывающего среднюю цену более чем по 20 биржам, по состоянию на 19.28 мск биткоин дорожал на 0,31%, до 8,736 тысячи долларов. На крупнейшей по объему торгов криптовалютами бирже Binance биткоин рос в цене на 0,13%, до 8,7 тысячи долларов. Но незадолго до этого оба показателя превысили 9 тысяч долларов, впервые с мая 2018 года.В то же время стоимость Ethereum росла на 2,3%, до 278,78 доллара, Ripple - на 1,83%, до 0,4561 доллара, а Bitcoin Cash - на 0,38%, до 458,72 доллара. По данным CoinMarketCap, капитализация рынка криптовалют составляет на данный момент 278,21 миллиарда долларов. На долю биткоина приходится примерно 52% рынка.Независимый эксперт Мансур Гусейнов пояснил РИА Новости, что резкий рост цены биткоина в последнее время связан с увеличением спроса после периода консолидации цены. "Нынешний рост биткоина можно объяснить эффектом накопления. С точки зрения технического анализа, в растущем тренде есть периоды консолидации, когда рынок торгуется возле достигнутой ценовой планки, причём колебания постепенно затихают. Затем идёт резкий выход, чаще всего в направлении тренда", - рассказал он.Рост стоимости биткоина произошел на фоне падения нефтяных цен на 2-3% после выхода данных о росте её добычи в США и более слабом снижении коммерческих запасов нефти за прошлую неделю по сравнению с прогнозами.Глава российского отделения сингапурской криптобиржи Huobi и вице-президент Российской ассоциации криптовалют и блокчейна (РАКИБ) по трейдингу Андрей Грачев отметил, что инвесторы переходят от классических активов к альтернативным, к которым в том числе относится биткоин, из-за внешнеполитической неопределенности. "Сейчас есть накопленный риск в связи с геополитическими конфликтами, и поэтому инвесторы переходят из классического рынка в рынок криптовалют, который не зависим от различных санкций и политики", - пояснил он.
#
# https://ria.ru/20190530/1555104036.html
#
# ('В ЦБ заявили, что криптовалюты пока не угрожают денежной системе России', '2019-05-30', 'Центральный Банк РФРоссияЭкономика')
#
#  МОСКВА, 30 мая - РИА Новости. Криптовалюты пока не угрожают денежной системе РФ, однако ЦБ против их легализации и использования как платежного инструмента, сообщила председатель Банка России Эльвира Набиуллина, отвечая на вопрос депутата в Госдуме."Объем криптовалют в мире не такой большой - 20 крупных криптовалют составляют около 250 миллиардов долларов США. Масштаб пока не очень большой, пока не угрожает нашей денежной системе. Но наша позиция здесь однозначна: мы против легализации криптовалюты именно как платежного средства", - сказала Набиуллина.По ее словам, ЦБ считает, что существуют большие риски для тех, кто держит криптовалюты. Также регулятор видит, как "скачут цены на криптовалюты", и считает, что нужно уберегать граждан от рисков вложений в такие волатильные активы, добавила Набиуллина.Вместе с тем, ЦБ видит потенциал в технологии - биткоин и другие криптовалюты стали так быстро развиваться, потому что через них можно быстро осуществлять платежи, указала глава ЦБ."Люди хотят быстрых платежей, поэтому мы развиваем Систему быстрых платежей (СБП). То есть абсолютно легальными прозрачными способами удовлетворить потребности добросовестных участников финансового рынка. Вот это наша задача", - подчеркнула Набиуллина.Кроме того, она добавила, что криптовалюты используются для отмывания денег.
#
# https://ria.ru/20190530/1555093653.html
#
# ('Как под Facebook подложили "закладку", и что это значит', '2019-05-30', 'АкцентыFacebookРоскомнадзорРоссия')
#
#  На запрещенную рекламу в ленте Facebook обратил внимание пользователь из российской столицы, пишет "КоммерсантЪ". Под стилизованным конопляным листом содержалось обещание хорошего отдыха и заработка. После того, как СМИ подняли шум, объявление удалили. Журналисты издания поинтересовались в администрации Facebook, как оно в принципе оказалось в ленте, но ответа не получили. При этом к сомнительному контенту крупнейшая соцсеть в мире старается подходить щепетильно. Особенно тщательно фильтруются разные неполиткорректности, разжигание ненависти и "обнаженка", причем, часто в пуританизме доходит до абсурда. И тут такое!Впрочем, подобное объявление могло оказаться, по большому счету, в любой соцсети или даже на обычном сайте, отметил в комментарии для радио Sputnik директор Ассоциации профессиональных пользователей социальных сетей и мессенджеров Владимир Зыков:Чаще всего борются с таким контентом сетевые активисты, продолжает Владимир Зыков. Для выявления сомнительных объявлений даже используются специальные программы:ТЕМНЫЕ СХЕМЫ Наркобизнес все больше уходит в Сеть, ведь так гораздо безопаснее для организаторов торговли. С покупателем они контактируют в даркнете, который обеспечивает анонимность, через Telegram – с "закладчиком". Последний вносит предоплату, забирает "товар" и прячет его по укромным местам, а конечный покупатель – удаленно получает координаты "закладки" и уходит оттуда уже с зельем в руках. Оплата – или в криптовалюте, или через онлайн-кошельки. Тем, кто зарекомендовал себя как надежный "закладчик", могут дать задание на партию покрупнее, или на работу "мула" – перевозчика оптового количества "товара". Над теми, кто пытается обмануть работодателя, могут учинить расправу или сдать правоохранителям. Иногда так поступают, чтобы не платить за работу.  Впрочем, ловят "закладчиков" и не по наводке, а в результате обычной оперативно-розыскной деятельности – благодаря работе патрульных или наблюдательности граждан. В результате увлечение "легкими" заработками может привести за решетку на 10 лет и более (ст. 228 УК РФ). Часто так попадают по наивности те, кого интернет-вербовщики ввели в заблуждение или насчет характера работы, или по поводу тяжести такого деяния. Как следствие – все больше молодежи получает сроки и ломает себе жизнь. А те, кто по возрасту еще не подлежит уголовной ответственности, начинают свои криминальные "карьеры", которые заканчиваются тоже вполне предсказуемо. ЕСЛИ КТО-ТО КОЕ-ГДЕ…Но ловят в основном именно мелких сошек. Организаторы наркотических онлайн-схем чаще всего остаются на свободе из-за сложности доказывания причастности к преступлению, пояснил в интервью радио Sputnik член президиума организации "Офицеры России", генерал-майор полиции в отставке Александр Яневский: Хотя винить во всем технический прогресс, наверное, было бы неправильно. В конце концов, объявления о поиске наркокурьеров и продаже наркотиков можно встретить на стенах российских городов. И здесь как с интернет-сайтами: сотрешь один, появятся два новых, посадишь одного – найдутся очередные желающие. Так что пока основная надежда в борьбе с "закладками" – на сетевых активистов.
#
# https://ria.ru/20190528/1554639391.html
#
# ('No title', 'No date listed', 'No title listed')
#
# Text under a different tag
#
# https://ria.ru/20190523/1554837420.html
#
# ('ЦБ готов рассмотреть криптовалюту для расчетов, привязанную к золоту', '2019-05-23', 'Эльвира НабиуллинаЦентральный Банк РФРоссияЭкономика')
#
#  МОСКВА, 23 мая - РИА Новости. ЦБ РФ готов рассмотреть предложение о создании криптовалюты, привязанной к золоту, для взаиморасчетов с другими странами, однако считает развитие расчетов в нацвалютах более перспективным, заявила на заседании комитета по финансовому рынку в Госдуме глава ЦБ Эльвира Набиуллина."Что касается взаиморасчетов: рассмотрим ваше предложение, что такое криптовалюта, привязанная к золоту. Но на мой взгляд важнее развивать все-таки расчеты в национальной валюте", - сказала Набиуллина в ответ на вопрос депутата Владимира Гутенева, готов ли ЦБ рассмотреть ли такую идею.Набиуллина отметила, что формат криптовалюты типа stable coin, которая привязана к реальному активу и обеспечению, изучается регулятором, и ее можно рассмотреть в регуляторной "песочнице" ЦБ. Вместе с этим ЦБ выступает против встраивания криптовалют в денежную систему РФ."Мы не видим этой возможности, чтобы криптовалюты здесь выполняли функцию денежных суррогатов, и практически не рассматриваем такие проекты в рамках регуляторной "песочницы", - подчеркнула Набиуллина.Стейблкоин (stable coin) - криптовалюты, которые привязаны к запасам фиатных валют или физических товаров. За счет этой привязки стоимость стейблкоинов менее волатильна, чем курсы традиционных криптовалют.
#
# https://ria.ru/20190523/1554832147.html
#
# ('Борщевой набор на Украине за год подорожал на 77%', '2019-05-23', 'УкраинаЭкономика')
#
#  КИЕВ, 23 мая – РИА Новости. Стоимость овощей борщового набора на Украине за год выросла на 77%, сообщил в четверг гендиректор Украинской ассоциации поставщиков торговых сетей Алексей Дорошенко."Ассоциация поставщиков торговых сетей исследовала, как изменились цены овощного корзины за апрель и за последний год по данным статистики. За последний год овощной набор подорожал на 77%", - написал Дорошенко на странице в Facebook.По его словам, за год стоимость лука выросла в 3,5 раза, капуста – 2,7 раза, цена на картофель увеличилась на 37%, свеклы -16%, морковь – 1,5%.Дорошенко подчеркнул, что за апрель 2019 года борщевой набор подорожал на 25%.
#
# https://ria.ru/20190517/1553566011.html
#
# ('Венесуэла ведет переговоры с Россией по переходу на расчеты в рублях', '2019-05-17', 'ВенесуэлаРоссияЭкономика')
#
#  ЖЕНЕВА, 17 мая – РИА Новости, Елизавета Исакова. Венесуэла ведет переговоры с Россией по переходу на расчеты в рублях, заявил РИА Новости посол Венесуэлы при женевском отделении ООН Хорхе Валеро.Валеро отметил, что Каракас в настоящее время ведет диалог с Москвой по вопросу о переходе на расчеты в рублях.Петро была выпущена в оборот с 20 февраля. Таким образом, Венесуэла стала первой страной с собственной криптовалютой, которая поддерживается запасами нефти. Изначально Мадуро определил стоимость 1 петро в цену одного барреля венесуэльской нефти, или 60 долларов, что составляет сейчас 9 тысяч суверенных боливаров по официальному курсу.В Венесуэле уже долгое время продолжается экономический кризис, усугубленный действием введенных против страны финансовых и экономических санкций. Санкции США против Венесуэлы действуют с марта 2015 года, когда президент Барак Обама ввел их против ряда венесуэльских чиновников в ответ на высылку из страны американских дипломатов. С тех пор санкции неоднократно расширялись. США в последнее время ужесточили ряд санкций против Венесуэлы, в том числе против государственных компаний. Вашингтон 28 января объявил о введении санкций в отношении национальной нефтегазовой компании Венесуэлы PDVSA.
#
# https://ria.ru/20190514/1553479505.html
#
# ('Белоусов призвал ускорить переход к цифровой экономике', '2019-05-14', 'Андрей БелоусовЭкономика')
#
#  МОСКВА, 14 мая - РИА Новости. Помощник президента РФ по экономическим вопросам, председатель наблюдательного совета АНО "Цифровая экономика" Андрей Белоусов призвал ускорить переход к цифровой экономике, в частности принять в 2019 году принять максимальное количество "цифровых" законов, говорится в сообщении АНО.Согласно релизу, набсовет АНО "Цифровая экономика" обсудил на апрельском заседании итоги законотворческой деятельности в рамках нацпрограммы "Цифровая экономика РФ". В частности, был рассмотрен статус исполнения ключевых вех федерального проекта "Нормативное регулирование". В заседании набсовета приняли участие представители администрации президента РФ, правительства РФ, Минкомсвязи РФ, обеих палат российского парламента и ведущих компаний цифровой экономики, которые входят в состав учредителей организации."Нам нужно серьёзно ускорить переход к цифровой экономике, для чего необходимо легализовать значительное количество инновационных практик, связанных с использованием цифровых технологий. В 2019 году необходимо принять максимальное количество "цифровых" законов, в том числе 12 ключевых законопроектов важно успеть внести в весеннюю сессию. Выполнение этой задачи будет возможным только в случае максимально скоординированной работы всех участников процесса, включая профильные министерства и аппарат правительства РФ", – приводятся в релизе слова Белоусова.В 2018 году набсовет АНО "Цифровая экономика" обозначил приоритеты принятия законопроектов Госдумой исходя из их важности для развития цифровой экономики. К настоящему времени принят закон о внедрении электронных сделок, которые позволяют заключать договоры посредством обмена электронными сообщениями вместо бумажных документов. В Госдуме также рассматривается законопроект о краудфандинге, который предусматривает новые способы осуществления инвестиций в бизнес-проекты через краудплатформы и их прозрачность.Помимо этого, четыре законопроекта проходят финальную подготовку в правительстве перед внесением в Госдуму. Среди них законопроект о регулировании электронной подписи, в том числе "облачной", а также введении института третьей доверенной стороны, законопроект об электронном делопроизводстве в нотариате, который сократит затраты времени на удостоверение документов и сделок для всех участников процесса, законопроект о 3D-моделях, который даёт возможность при подаче заявок на регистрацию интеллектуальной собственности представлять изобретения в виде цифровых трехмерных моделей и законопроект об отмене бумажных трудовых книжек, который предусматривает ведение данных о трудовой деятельности работников в электронном виде.Еще ряд законопроектов, в том числе о льготном налогообложении IT-компаний, об идентификации, включая электронный паспорт, криптовалютах, электронном архиве, одобрены на заседании президиума правительственной комиссии по цифровому развитию или проходят согласование в правительстве РФ.
#
# https://ria.ru/20190514/1553462998.html
#
# ('Биткоин за неделю подорожал на треть', '2019-05-14', 'БиткойнВ миреЭкономика')
#
#  МОСКВА, 14 мая - РИА Новости. Стоимость самой популярной криптовалюты - биткоина – во вторник впервые с июля 2018 года превысила психологическую отметку в 8 тысяч долларов, свидетельствуют данные торгов.По данным портала CoinMarketCap, высчитывающего среднюю цену более чем по 20 биржам, по состоянию на 0.52 мск биткоин дорожал на 13,62%, до 8,022 тысячи долларов.Седьмого мая биткоин превысил отметку в 6 тысяч долларов, 12 мая - в 7 тысяч долларов.
#
# https://ria.ru/20190512/1553428240.html
#
# ('Стоимость биткоина впервые с октября превысила семь тысяч долларов', '2019-05-12', 'Динамика курсов валютЭкономика')
#
#  МОСКВА, 12 мая - РИА Новости. Стоимость самой популярной криптовалюты - биткоина - в воскресенье впервые с октября 2018 года превысила психологическую отметку в 7 тысяч долларов, свидетельствуют данные торгов.По данным портала CoinMarketCap, высчитывающего среднюю цену более чем по 20 биржам, по состоянию на 17.54 мск биткоин дорожал на 3,51%, до 7,054 тысячи долларов. На крупнейшей по объему торгов криптовалютами бирже Binance биткоин рос в цене на 3,21%, до 7,001 тысячи долларов, впервые с 15 октября прошлого года преодолев уровень в 7 тысяч долларов.В то же время стоимость Ethereum снижается на 1,49%, до 186,96 доллара, Ripple - на 2,36%, до 0,3108 доллара, а Bitcoin Cash - растет на 9,13%, до 350,29 доллара. По данным CoinMarketCap, капитализация рынка криптовалют составляет на данный момент 211,405 миллиарда долларов. На долю биткоина приходится примерно 59,1% рынка.Президент аналитического агентства "БизнесДром", член экспертного совета Госдумы по цифровой экономике Арсений Поярков связывает такой рост цены биткоина со спекулянтами."Биткоин пробил 7 тысяч долларов на фоне исключительно негативных новостей - взлома одной из крупнейших бирж, а также развитии негативного фона вокруг криптовалют в США. Ставлю на то, что это манипуляция рынком для привлечения новых покупателей для дальнейшей продажи большого объема", - прокомментировал он РИА Новости.Поярков пояснил, что рынок криптовалют "исключительно манипулятивный", и крупные держатели могут обеспечить такой рост за счет собственных ресурсов, чтобы на рынок пришли покупатели, надеющиеся на дальнейший рост. "Как только покупатели в нужном объеме придут, "киты" начнут продажи и биток сильно просядет", - добавил он.
#
# https://ria.ru/20190508/1553351782.html
#
# ('Россияне смогут оплатить по QR-коду покупки стоимостью до 600 тысяч рублей', '2019-05-08', 'ГазпромбанкВТБПромсвязьбанкМоскваРоссияЭкономика')
#
#  МОСКВА, 8 мая - РИА Новости. Россияне смогут оплачивать с помощью QR-кода покупки стоимостью до 600 тысяч рублей, сообщил РИА Новости директор по развитию платежных решений производителя онлайн-касс "Эвотор" Заур Бесолов.По его словам, тестирование нового сервиса начнется 30 августа, в начале он будет доступен в небольших магазинах."Первые пилоты с высокой вероятностью мы увидим 30 августа. Поначалу это будут небольшие магазинчики и торговля на рынках. Пока для оплаты товаров и услуг установлен общий лимит до 600 тысяч для совершения одной операции. Сегодня рассматриваются различные сценарии оплаты как с помощью динамического, так и статического QR-кода. В любом случае, покупателей в России ожидает новый и интересный клиентской опыт, я прогнозирую бум QR-оплат в 2020 году", - сказал эксперт.По словам Бесолова, дата промышленного запуска сервиса определится позднее - все будет зависеть от того, насколько успешным будет пилотный проект.Оплата товаров с помощью QR-кода станет возможной благодаря запуску расширенной версии системы быстрых платежей. Система была запущена в феврале 2019 года, россияне благодаря ей могут переводить деньги по номеру телефона. Пока в системе 12 участников: ВТБ, "Тинькофф банк", Промсвязьбанк, Росбанк, СКБ-банк, Газпромбанк, Альфа-банк, "Ак Барс", Райффайзенбанк, платежный сервис Qiwi, Совкомбанк и РНКО "Платежный центр" - оператор платежной системы "Золотая Корона".В перспективе с помощью системы быстрых платежей оплачивать товары и услуги можно будет не только в обычных, но и в интернет-магазинах, отмечал в апреле начальник управления инноваций Национальной системы платежных карт (НСПК) Дмитрий Колесников.
#
# https://ria.ru/20190508/1553348973.html
#
# ('Хакеры взломали криптобиржу и похитили биткоинов на 41 миллион долларов', '2019-05-08', 'В мире')
#
#  МОСКВА, 8 мая - РИА Новости. Хакеры взломали одну из крупнейших криптобирж в мире по объему торгов - Binance - и похитили биткоины почти на 41 миллион долларов, говорится в сообщении компании Binance."Мы обнаружили крупное нарушение безопасности... 7 мая 2019 года, в 17.15 по UTC (20.15 мск - ред.). Хакерам удалось получить большое количество API-ключей пользователей, коды двухфакторной аутентификации и, возможно, другую информацию. Хакеры использовали различные методы, включая фишинг, вирусы и другие атаки", - сообщается в релизе. В итоге злоумышленникам удалось с помощью одной операции вывести 7 тысяч биткоинов (около 40,8 миллиона долларов по текущему курсу).Уточняется, что средства были выведены через "горячий" (активный) счет биткоинов (на котором было около 2% от общего количества биткоинов криптобиржи). Все остальные кошельки компании остались в сохранности. Криптобиржа намерена покрыть убыток за счет своего фонда SAFU, средства пользователей при этом не будут затронуты.Вместе с этим Binance приостановит на неделю возможность ввода и вывода средств из-за технических работ. "Мы должны провести тщательный анализ систем безопасности... Мы рассчитываем, что он займет около недели", - указали в компании. При этом пользователи по-прежнему смогут торговать на криптобирже.Компания отметила, что хакеры могут по-прежнему контролировать определенные учетные записи пользователей и использовать их для влияния на стоимость криптовалют. "Мы будем внимательно следить за ситуацией. Но мы полагаем, что с отключением возможности вывода средств у хакеров не будет особых стимулов влиять на рынки", - говорится в сообщении.
#
# https://ria.ru/20190507/1553334565.html
#
# ('Стоимость биткоина впервые с ноября превысила шесть тысяч долларов', '2019-05-07', 'Экономика')
#
#  МОСКВА, 7 мая - РИА Новости. Стоимость самой популярной криптовалюты - биткоина - во вторник впервые с ноября 2018 года превысила психологическую отметку в 6 тысяч долларов, свидетельствуют данные торгов и комментарии аналитиков.По данным портала CoinMarketCap, высчитывающего среднюю цену более чем по 20 биржам, по состоянию на 17.44 мск биткоин дорожал на 3,22%, до 5,901 тысячи долларов. На крупнейшей по объему торгов криптовалютами бирже Binance биткоин рос в цене на 3,26%, до 5,903 тысячи долларов. При этом ранее в ходе торгов стоимость криптовалюты достигала отметки в 6,028 тысячи долларов, впервые с 14 ноября прошлого года преодолев уровень в 6 тысяч долларов.Стоимость других популярных криптовалют также растет: Ethereum - на 3,95%, до 173,29 доллара, Ripple - на 0,34%, до 0,3019 доллара, Bitcoin Cash - на 0,10%, до 288,4 доллара. По данным CoinMarketCap, капитализация рынка криптовалют составляет на данный момент 186,41 миллиарда долларов. На долю биткоина приходится примерно 56% рынка.Как прокомментировал РИА Новости независимый эксперт Мансур Гусейнов, криптовалюта растет в цене в связи с завершением "медвежьего" цикла, который длился ровно год, начиная с 15 декабря 2017 года. "Завершение цикла связано с тем, что инвесторы, которые не могли или боялись держать (криптовалюту - ред.), на падающем рынке избавились от позиций, и спрос превысил "давление" продавцов", - пояснил он.По мнению эксперта, стоимость битокина дойдет до диапазона 6,3-6,5 тысячи долларов, однако после этого снизится. "С высокой вероятностью цены дойдут до этого уровня и отскочат вниз, поскольку инвесторы, заходившие ниже, захотят зафиксировать прибыль. ... Вероятно, мы будем находиться в некоем диапазоне в течение полугода-года, прежде чем начнется новый цикл роста. Инвестиционная привлекательность биткоина осталась неизменной, поэтому рост, на мой взгляд, неизбежен", - добавил он.
#
# https://ria.ru/20190504/1553250725.html
#
# ('В Бразилии задержали подозреваемого в торговле наркотиками в "даркнете"', '2019-05-04', 'БразилияСШАВ мире')
#
#  ВАШИНГТОН, 4 мая - РИА Новости, Алексей Богдановский. Четвертый подозреваемый задержан в Бразилии по делу крупной торговой площадки в теневом сегменте интернета ("даркнете"), сообщил в заявлении федеральный прокурор США Ник Ханна.Как сообщалось в пятницу, генеральная прокуратура Франкфурта-на-Майне и федеральное ведомство уголовной полиции Германии (BKA) задержали трех предполагаемых администраторов второй по величине нелегальной торговой площадки в "даркнете" Wall Street Market."Четвертому обвиняемому, связанному с Wall Street Market, предъявлены обвинения в окружном суде США в Сакраменто, штат Калифорния. Маркос Пауло де Оливейра-Аннибале, которому 29 лет и который является жителем Сан-Паулу в Бразилии, также обвиняется в федеральном суде в распространении наркотиков и отмывании денег за предполагаемую деятельность в качестве модератора сайта", - говорится в заявлении прокурора США.По его данным, Аннибале занимался урегулированием споров между продавцами и покупателями сайта и осуществлял пиар-кампанию, продвигая площадку на внешних сайтах. Аннибале был задержан по месту жительства.Согласно заявлению германских ведомств, расследование было проведено при участии правоохранительных органов США, ФБР, полиции Нидерландов и Европола. Сообщается, что Wall Street Market являлась второй по величине нелегальной торговой площадкой в мире. Она использовалась для торговли наркотиками, похищенными данными, поддельными документами и вредоносными программами. По данным немецких СМИ, площадку закрыли в четверг. По данным правоохранителей, на Wall Street Market было размещено более 63 тысяч предложений о продаже, зарегистрировано более 1 миллиона учетных записей клиентов и более 5,4 тысячи продавцов. Пользователи оплачивали товары криптовалютами.В ходе обысков у подозреваемых в Германии нашли 550 тысяч евро, а также шестизначные суммы в криптовалютах Bitcoin и Monero и дорогостоящие автомобили. Кроме того, у одного из подозреваемых было найдено огнестрельное оружие.
#
# https://ria.ru/20190503/1553245087.html
#
# ('В Германии задержали предполагаемых хозяев торговой площадки в "даркнете"', '2019-05-03', 'ГерманияВ мире')
#
#  МОСКВА, 3 мая - РИА Новости. Генеральная прокуратура Франкфурта-на-Майне и федеральное ведомство уголовной полиции Германии (BKA) задержали троих предполагаемых администраторов второй по величине нелегальной торговой площадки в теневом сегменте интернета ("даркнете"), говорится в совместном заявлении ведомств, опубликованных в пятницу.Согласно заявлению, расследование было проведено при участии правоохранительных органов США, ФБР, полиции Нидерландов и Европола. В результате 23 и 24 апреля в городах Клеве, Бад-Фильбель и в районе Эсслингер были задержаны трое граждан ФРГ в возрасте 31, 29 и 22 лет. Их подозревают в управлении нелегальной торговой площадкой Wall Street Market. В их квартирах прошли обыски.Сообщается, Wall Street Market – вторая по величине нелегальная торговая площадка в мире. Она используется для торговли наркотиками, похищенными данными, поддельными документами и вредоносными программами. По данным немецких СМИ, площадку закрыли в четверг.По данным правоохранителей, на Wall Street Market было размещено более 63 тысяч предложений о продаже, зарегистрировано более 1 миллиона учетных записей клиентов и более 5,4 тысячи продавцов. Пользователи оплачивали товары криптовалютами. Отмечается, что со 2 мая серверная инфраструктура платформы находится под контролем BKA.В ходе обысков у подозреваемых нашли 550 тысяч евро, а также шестизначные суммы в криптовалютах Bitcoin и Monero и дорогостоящие автомобили. Кроме того, у одного из подозреваемых было найдено огнестрельное оружие.
#
#
#
# Building data frame...
#                                        URLS  \
# 0   https://ria.ru/20190530/1555125701.html
# 1   https://ria.ru/20190530/1555104036.html
# 2   https://ria.ru/20190530/1555093653.html
# 3   https://ria.ru/20190528/1554639391.html
# 4   https://ria.ru/20190523/1554837420.html
# 5   https://ria.ru/20190523/1554832147.html
# 6   https://ria.ru/20190517/1553566011.html
# 7   https://ria.ru/20190514/1553479505.html
# 8   https://ria.ru/20190514/1553462998.html
# 9   https://ria.ru/20190512/1553428240.html
# 10  https://ria.ru/20190508/1553351782.html
# 11  https://ria.ru/20190508/1553348973.html
# 12  https://ria.ru/20190507/1553334565.html
# 13  https://ria.ru/20190504/1553250725.html
# 14  https://ria.ru/20190503/1553245087.html
#
#                                              metadata  \
# 0   (Стоимость биткоина впервые за год превысила д...
# 1   (В ЦБ заявили, что криптовалюты пока не угрожа...
# 2   (Как под Facebook подложили "закладку", и что ...
# 3         (No title, No date listed, No title listed)
# 4   (ЦБ готов рассмотреть криптовалюту для расчето...
# 5   (Борщевой набор на Украине за год подорожал на...
# 6   (Венесуэла ведет переговоры с Россией по перех...
# 7   (Белоусов призвал ускорить переход к цифровой ...
# 8   (Биткоин за неделю подорожал на треть, 2019-05...
# 9   (Стоимость биткоина впервые с октября превысил...
# 10  (Россияне смогут оплатить по QR-коду покупки с...
# 11  (Хакеры взломали криптобиржу и похитили биткои...
# 12  (Стоимость биткоина впервые с ноября превысила...
# 13  (В Бразилии задержали подозреваемого в торговл...
# 14  (В Германии задержали предполагаемых хозяев то...
#
#                                               content        date
# 0    МОСКВА, 30 мая - РИА Новости. Стоимость самой...  2019-05-30
# 1    МОСКВА, 30 мая - РИА Новости. Криптовалюты по...  2019-05-30
# 2    На запрещенную рекламу в ленте Facebook обрат...  2019-05-30
# 3                          Text under a different tag  2019-05-28
# 4    МОСКВА, 23 мая - РИА Новости. ЦБ РФ готов рас...  2019-05-23
# 5    КИЕВ, 23 мая – РИА Новости. Стоимость овощей ...  2019-05-23
# 6    ЖЕНЕВА, 17 мая – РИА Новости, Елизавета Исако...  2019-05-17
# 7    МОСКВА, 14 мая - РИА Новости. Помощник презид...  2019-05-14
# 8    МОСКВА, 14 мая - РИА Новости. Стоимость самой...  2019-05-14
# 9    МОСКВА, 12 мая - РИА Новости. Стоимость самой...  2019-05-12
# 10   МОСКВА, 8 мая - РИА Новости. Россияне смогут ...  2019-05-08
# 11   МОСКВА, 8 мая - РИА Новости. Хакеры взломали ...  2019-05-08
# 12   МОСКВА, 7 мая - РИА Новости. Стоимость самой ...  2019-05-07
# 13   ВАШИНГТОН, 4 мая - РИА Новости, Алексей Богда...  2019-05-04
# 14   МОСКВА, 3 мая - РИА Новости. Генеральная прок...  2019-05-03
#
#
# Exporting data...
